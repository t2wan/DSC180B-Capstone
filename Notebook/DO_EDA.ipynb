# %% [markdown]
# Input Analysis

# %% [markdown]
# What are the length distributions of documents and sentences? Any outliers?

# %%
from IPython.display import Image
Image("../data/eda/DBLP_outlier.png")

# %% [markdown]
# Boxplot Visual would give a better view of the length of documents.

# %%
Image("../data/eda/DBLP_boxplot.png")

# %% [markdown]
# After removing the outliers..

# %%
Image("../data/eda/DBLP cleaned_set.png")

# %% [markdown]
# What is the distribution of all tokens? How many "rare" tokens (e.g., < 5 times)?

# %%
Image("../data/eda/DBLP tokens_distribution.png")

# %%
f = open("../data/eda/DBLP description.txt", "r")
print(f.read())
# Out:
# Mean for length distribution is 33.03413347563427. Std is 56.569666700975866. Number of Rare tokens is 937470 .

# %% [markdown]
# Output Analysis

# %% [markdown]
# Run AutoPhrase, and then plot the quality score distribution of single-word and multi-word phrases separately.

# %%
Image("../data/outputs/DBLP multi_value_distribution.png")

# %%
Image("../data/outputs/DBLP single_value_distribution.png")

# %% [markdown]
# Obviously single word generally has a higher quality score.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/outputs/DBLP AutoPhrase_multi-words.txt',sep='\t',header=None)
df.columns = ['Score','Words']

# %%
subset = df[df['Score']>0.5].sample(100)

# %%
subset.sort_values('Score',ascending=False)
# Out:
#            Score                       Words
# 7114    0.934549        infinite dimensional
# 8277    0.931126              usage patterns
# 10866   0.923437           amer math monthly
# 12882   0.917795          baseband processor
# 13276   0.916711  interstitial lung diseases
# ...          ...                         ...
# 213724  0.513080                adaptive gop
# 215398  0.510143            tight worst case
# 218252  0.505029          network aware grid
# 219040  0.503694                   $ \ \ bbb
# 220117  0.501800           damages caused by
#
# [100 rows x 2 columns]
